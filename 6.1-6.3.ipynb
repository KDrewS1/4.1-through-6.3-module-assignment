# %%
number= ["3", "2", "1", "0"]
range(3)
if input: number[3]
else:
  input: number[2]
  input: number[1]
  input: number[0]
print("found it ")
 
if input: range(+4)
else:
 [5] or [7] 
for number in [5, 7]:
 print("oops greater than")
